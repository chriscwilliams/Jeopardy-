# %%
import pandas as pd

# Importing CSV file
dataset = pd.read_csv("jeopardy.csv")

dataset
# Out:
#         Show Number    Air Date      Round                         Category  \
# 0       4680         2004-12-31  Jeopardy!  HISTORY
# 1       4680         2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES
# 2       4680         2004-12-31  Jeopardy!  EVERYBODY TALKS ABOUT IT...
# 3       4680         2004-12-31  Jeopardy!  THE COMPANY LINE
# 4       4680         2004-12-31  Jeopardy!  EPITAPHS & TRIBUTES
# ...      ...                ...        ...                  ...
# 116845  3174         1998-05-21  Jeopardy!  NONFICTION
# 116846  3174         1998-05-21  Jeopardy!  PIG-OUT
# 116847  3174         1998-05-21  Jeopardy!  SPORTS
# 116848  3174         1998-05-21  Jeopardy!  CANADIAN CITIES
# 116849  3174         1998-05-21  Jeopardy!  REPORTERS' QUE
#
#         Value  \
# 0       $200
# 1       $200
# 2       $200
# 3       $200
# 4       $200
# ...      ...
# 116845  $500
# 116846  $500
# 116847  $500
# 116848  $500
# 116849  NaN
#
# ...

# %%
def word_filter(dataset, words):
    filter = lambda x: all(word.lower() in x.lower() for word in words)
    return dataset.loc[dataset[" Question"].apply(filter)]

word_filter(dataset, ["Leap", "Day"])
